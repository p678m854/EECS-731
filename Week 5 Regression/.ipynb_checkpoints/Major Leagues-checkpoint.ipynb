# %% [markdown]
# # Major Leagues
# ## General Information
# 1. Author: Patrick McNamee
# 2. Date: 10/11/2019
# ## Description
# Analyzing the soccer, i.e. "football", spi from [538](https://github.com/fivethirtyeight/data/tree/master/soccer-spi). The goal of this notebook is to get models to predic the scores for each team playing each other.
#
# ## Data Engineering
# First we need to load the data into a data frame and then examine what information we have available.

# %%
import pandas as pd

df = pd.read_csv("./data/spi_matches.csv")
df = df.dropna()
df.head()
# Out:
#          date  league_id                   league           team1  \
# 0  2016-08-12       1843           French Ligue 1          Bastia
# 1  2016-08-12       1843           French Ligue 1       AS Monaco
# 2  2016-08-13       2411  Barclays Premier League       Hull City
# 3  2016-08-13       2411  Barclays Premier League  Crystal Palace
# 4  2016-08-13       2411  Barclays Premier League         Everton
#
#                   team2   spi1   spi2   prob1   prob2  probtie     ...      \
# 0   Paris Saint-Germain  51.16  85.68  0.0463  0.8380   0.1157     ...
# 1              Guingamp  68.85  56.48  0.5714  0.1669   0.2617     ...
# 2        Leicester City  53.57  66.81  0.3459  0.3621   0.2921     ...
# 3  West Bromwich Albion  55.19  58.66  0.4214  0.2939   0.2847     ...
# 4     Tottenham Hotspur  68.02  73.25  0.3910  0.3401   0.2689     ...
#
#    importance1  importance2  score1  score2   xg1   xg2  nsxg1  nsxg2  \
# ...

# %% [markdown]
# There appears to be some previous work done by 538 has there are scores, projected scores, and adjusted scores. First thing to do is remove the both projective scores and adjusted slore columns as they could possible influence any models built through a preconcieved bias.

# %%
df = df.drop("adj_score1", axis=1)
df = df.drop("adj_score2", axis=1)
df = df.drop("proj_score1", axis=1)
df = df.drop("proj_score2", axis=1)
df.head()
# Out:
#          date  league_id                   league           team1  \
# 0  2016-08-12       1843           French Ligue 1          Bastia
# 1  2016-08-12       1843           French Ligue 1       AS Monaco
# 2  2016-08-13       2411  Barclays Premier League       Hull City
# 3  2016-08-13       2411  Barclays Premier League  Crystal Palace
# 4  2016-08-13       2411  Barclays Premier League         Everton
#
#                   team2   spi1   spi2   prob1   prob2  probtie  importance1  \
# 0   Paris Saint-Germain  51.16  85.68  0.0463  0.8380   0.1157         32.4
# 1              Guingamp  68.85  56.48  0.5714  0.1669   0.2617         53.7
# 2        Leicester City  53.57  66.81  0.3459  0.3621   0.2921         38.1
# 3  West Bromwich Albion  55.19  58.66  0.4214  0.2939   0.2847         43.6
# 4     Tottenham Hotspur  68.02  73.25  0.3910  0.3401   0.2689         31.9
#
#    importance2  score1  score2   xg1   xg2  nsxg1  nsxg2
# ...

# %% [markdown]
# There are a couple features that can be made from the given columns in the data frame. The first set is to get the month, day, and year of the match into numerical values for evaluation. The second set is that the teams are given in an order pair so would be nice to know the averages and then signed difference of attributes between the teams for various things. The attributes that this will be applied to is the spi and the score.

# %%
#numeric dates
df['year'] = df['date'].map(lambda x: int(x.split('-')[0]))
df['month'] = df['date'].map(lambda x: int(x.split('-')[1]))
df['day'] = df['date'].map(lambda x: int(x.split('-')[2]))

# average and deltas
df['avg_spi'] = (df['spi1'] + df['spi2'])/2
df['delta_spi'] = (df['spi1'] - df['spi2'])
df['avg_score'] = (df['score1'] + df['score2'])/2
df['delta_score'] = (df['score1'] - df['score2'])
df['avg_importance'] = (df['importance1'] + df['importance2'])/2
df['delta_importance'] = (df['importance1'] - df['importance2'])

df.head()
# Out:
#          date  league_id                   league           team1  \
# 0  2016-08-12       1843           French Ligue 1          Bastia
# 1  2016-08-12       1843           French Ligue 1       AS Monaco
# 2  2016-08-13       2411  Barclays Premier League       Hull City
# 3  2016-08-13       2411  Barclays Premier League  Crystal Palace
# 4  2016-08-13       2411  Barclays Premier League         Everton
#
#                   team2   spi1   spi2   prob1   prob2  probtie  \
# 0   Paris Saint-Germain  51.16  85.68  0.0463  0.8380   0.1157
# 1              Guingamp  68.85  56.48  0.5714  0.1669   0.2617
# 2        Leicester City  53.57  66.81  0.3459  0.3621   0.2921
# 3  West Bromwich Albion  55.19  58.66  0.4214  0.2939   0.2847
# 4     Tottenham Hotspur  68.02  73.25  0.3910  0.3401   0.2689
#
#          ...         nsxg2  year  month  day  avg_spi  delta_spi  avg_score  \
# 0        ...          0.45  2016      8   12   68.420     -34.52        0.5
# ...

# %% [markdown]
# For ease of modeling use, I will use all data from before 2019 as training data and everything from 2019 as testing data to evaluate the various model results.

# %%
training = df[df['year'] <= 2018]
training = training.reset_index(drop=True)
training.tail()
# Out:
#             date  league_id                   league              team1  \
# 8417  2018-12-30       2411  Barclays Premier League        Southampton
# 8418  2018-12-30       1856            Italy Serie B          Benevento
# 8419  2018-12-30       2411  Barclays Premier League  Manchester United
# 8420  2018-12-30       1856            Italy Serie B            Livorno
# 8421  2018-12-30       1856            Italy Serie B             Spezia
#
#                 team2   spi1   spi2   prob1   prob2  probtie  \
# 8417  Manchester City  66.79  91.81  0.1363  0.6801   0.1837
# 8418          Brescia  31.06  34.62  0.3902  0.3223   0.2875
# 8419  AFC Bournemouth  78.36  64.51  0.6312  0.1616   0.2072
# 8420           Padova  21.62  17.82  0.4906  0.2134   0.2960
# 8421            Lecce  29.41  26.79  0.4496  0.2460   0.3044
#
#             ...         nsxg2  year  month  day  avg_spi  delta_spi  \
# 8417        ...          2.30  2018     12   30   79.300     -25.02
# ...

# %%
testing = df[df['year'] == 2019]
testing = testing.reset_index(drop=True)
testing.tail()
# Out:
#             date  league_id              league     team1             team2  \
# 3922  2019-10-09       2105  Brasileiro Série A     Bahía         São Paulo
# 3923  2019-10-09       2105  Brasileiro Série A  Cruzeiro        Fluminense
# 3924  2019-10-09       2105  Brasileiro Série A    Santos         Palmeiras
# 3925  2019-10-10       2105  Brasileiro Série A      Avaí     Vasco da Gama
# 3926  2019-10-10       2105  Brasileiro Série A  Flamengo  Atletico Mineiro
#
#        spi1   spi2   prob1   prob2  probtie        ...         nsxg2  year  \
# 3922  55.32  57.60  0.4429  0.2564   0.3007        ...          0.56  2019
# 3923  50.04  49.45  0.5202  0.2292   0.2506        ...          0.55  2019
# 3924  60.26  68.30  0.3620  0.3643   0.2737        ...          0.55  2019
# 3925  38.77  51.21  0.3604  0.3573   0.2823        ...          1.26  2019
# 3926  73.23  54.10  0.7637  0.0787   0.1576        ...          1.03  2019
#
# ...

# %% [markdown]
# From the indexing it looks to be roughly a 70% train and 30% test split which is a decent initial split. As more games are played then more data will be added to the training set. Next thing to do is save the training and testing data and begin making the models.

# %%
training.to_csv(r'./data/training_set.csv')
testing.to_csv(r'./data/testing_set.csv')

# %% [markdown]
# ## Data Exploration
# Okay, lets look at scatter plots and some distributions to see if there are some visual data relations that jump out.

# %%
#for ease of reference in edits
training = pd.read_csv(r'./data/training_set.csv')
testing = pd.read_csv(r'./data/testing_set.csv')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

pd.plotting.scatter_matrix(training[['avg_score', 'delta_score', 'avg_spi', 'delta_spi']])
plt.show()

# %%
plt.figure()
pd.plotting.scatter_matrix(training[['avg_score', 'delta_score',
                                     'avg_importance',
                                     'delta_importance']])
plt.show()

# %%
plt.figure()
maxscore = training.loc[:, ['score1', 'score2']].max(axis=1)
minscore = training.loc[:, ['score1', 'score2']].min(axis=1)
plt.plot(maxscore, minscore, marker='.', linestyle="None")
ax = plt.gca()
ax.set_xlabel(r'Max Score')
ax.set_ylabel(r'Min Score')
plt.show()

# %%
plt.figure()
plt.plot(training.loc[:, 'delta_spi'], training.loc[:, 'delta_score'], marker='.', linestyle="None")
ax = plt.gca()
ax.set_xlabel(r'$\Delta$SPI')
ax.set_ylabel(r'$\Delta$Score')
plt.show()

# %%
plt.figure()
plt.plot(training.loc[:, 'delta_importance'], training.loc[:, 'delta_score'], marker='.', linestyle="None")
ax = plt.gca()
ax.set_xlabel(r'$\Delta$Importance')
ax.set_ylabel(r'$\Delta$Score')
plt.show()

# %%
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')


sns.set(color_codes=True)
sns.distplot(training.loc[:,'avg_score'], kde=False, fit=stats.gamma)

# %%
maxmin = pd.concat([maxscore, minscore],
                   names=["Max Score", "Min Score"],
                   axis=1)
maxmin.columns = ['Max Score', 'Min Score']
sns.jointplot(x="Max Score", y="Min Score", data=maxmin)

# %% [markdown]
# ### Comments on Data Exploration
# 1. So there appears to be a positive correlation between the score difference and the SPI difference as well as score difference and importance factor although the second appears to be significantly less correlated.
#
# 2. The average score appears to be uncorrelated with everything although it can be fitted fairly well with a gamma distribution which has a PDF in the following form:
#
# $$f(x; \alpha, \beta) = \frac{\beta^\alpha}{\Gamma (\alpha)} x^{\alpha - 1}e^{-\beta x}$$
#
# 3. There seems to be a discrepancy between the distributions of the maximum score and the minimum score of the match. What may be able to be done is to determine which team is more likely to be the maximum and the other the minimum and then pull from the distributions.

# %% [markdown]
# ## Model Building
# ### Linear Regression mixed with Gamma Distribution
# First model is going to be a custom regression where (score1, score2) is determined by (average score, average score) + (delta score, - delta score). The average score is estimated using the gamma distribution and the the delta is made using a linear regression such that:
# $$\Delta\text{score} = a_0 + a_1 \Delta\text{SPI} + a_2 \Delta\text{Importance}$$

# %%
from scipy.stats import gamma

#scale = 1/beta
#loc is a shift
alpha, loc, scale = gamma.fit(training.loc[:, 'avg_score'])

#Simply to check it versus 
plt.figure()
sns.distplot(gamma.rvs(alpha, loc=loc, scale=scale, size=1000))
plt.show()

# %%
from sklearn import linear_model

delta_score = linear_model.LinearRegression()

linear_features = ['delta_spi', 'delta_importance']
X = training.loc[:, linear_features]
y = training.loc[:, 'delta_score']

delta_score.fit(X,y)
print(delta_score.coef_, delta_score.intercept_)
# Out:
# [0.05219597 0.00276307] 0.39554302260886726

# %%
delta_score.score(X,y)
# Out:
# 0.1913048772965097

# %% [markdown]
# ### Random Forest Regression
# The other model that I want to try is a random forest regressor since there seems to be a lot of randomness in data and scores are mostly integer classes anyways. This model will take all the inputs that belonging to the original 538 data set and try to predict a teams score. There will be two forests, one for Team 1 and another for Team 2.

# %%
from sklearn.ensemble import RandomForestRegressor

#Data setup
forest_features = ['spi1', 'spi2',
                   'prob1', 'prob2', 'probtie',
                   'importance1', 'importance2']
X = training.loc[:, forest_features]
y1 = training.loc[:, 'score1']
y2 = training.loc[:, 'score2']

#Random forest setup
team1 = RandomForestRegressor(n_estimators=100, 
                              max_depth=4,
                              oob_score=True)
team2 = RandomForestRegressor(n_estimators=100, 
                              max_depth=4,
                              oob_score=True)

#Fitting the random forests
team1.fit(X, y1)
team2.fit(X, y2)

print(team1.score(X,y1), team2.score(X,y2))
# Out:
# 0.1540114694820358 0.13157992778576388

# %%
for f, f1, f2 in zip(forest_features, team1.feature_importances_, team2.feature_importances_):
    print('{}:\t{}\t{}'.format(f, f1, f2))
# Out:
# spi1:	0.033268841749442626	0.017965402012230607
# spi2:	0.02742927113286858	0.03538057706179602
# prob1:	0.7195043120215662	0.1330889654001121
# prob2:	0.015013147007968266	0.6761741257619268
# probtie:	0.17488972079409287	0.08079237975548352
# importance1:	0.013707288758815224	0.04068232301469132
# importance2:	0.016187418535246335	0.015916226993759844

# %% [markdown]
# ## Model Testing
# Now that the models are built, time to test them. There will be two tests:
#
# 1. Mean Square Error (no rounding)
# 2. Score Correct Count (Rounding)
#
# The reason to do two tests is simply to see if the models can predict the correct match outcome as well as the scores. You may be willing to accept accuracy errors in scores if the models can always predict the match outcome.

# %%
# Setting up counters
count = 0
linear_score_correct = 0
linear_match_correct = 0
forest_score_correct = 0
forest_match_correct = 0

#Sum of Square Error counts
linear_SSE = 0
forest_SSE = 0

#Iterating through testing data
for i in testing.index:
    count = count + 1

    #Getting true values
    score1 = testing.loc[i,'score1']
    score2 = testing.loc[i,'score2']
    result = 0 #default tie
    if score1 > score2:
        result = 1
    elif score1 < score2:
        result = -1

    #Linear model
    avg_score = gamma.rvs(alpha, loc=loc, scale=scale, size=1)
    lds = delta_score.predict([testing.loc[i, linear_features]])
    ls1 = avg_score[0] + lds[0]
    ls2 = avg_score[0] - lds[0]
    #game result
    lr = 0 #tie
    if round(ls1) > round(ls2):
        lr = 1
    elif round(ls1) < round(ls2):
        lr = -1

    #Forest prediction
    fs1 = team1.predict([testing.loc[i, forest_features]])
    fs2 = team2.predict([testing.loc[i, forest_features]])
    fs1 = fs1[0]
    fs2 = fs2[0]
    #game result
    fr = 0 #tie
    if round(fs1) > round(fs2):
        fr = 1
    elif round(fs1) < round(fs2):
        fr = -1

    #updating SSE
    linear_SSE = linear_SSE + (ls1 - score1) ** 2 + (ls2 - score2) ** 2
    forest_SSE = linear_SSE + (fs1 - score1) ** 2 + (fs2 - score2) ** 2

    #Checking score and match of linear model
    if score1 == round(ls1):
        linear_score_correct = linear_score_correct + 1
    if score2 == round(ls2):
        linear_score_correct = linear_score_correct + 1
    if result == lr:
        linear_match_correct = linear_match_correct + 1
    #Checking score and match of forest model
    if score1 == round(fs1):
        forest_score_correct = forest_score_correct + 1
    if score2 == round(ls2):
        forest_score_correct = forest_score_correct + 1
    if result == fr:
        forest_match_correct = forest_match_correct + 1

# %%
print('Linear Model Results:')
print('MSE = {}'.format(linear_SSE/count))
print('Score Accuracy = {}'.format(linear_score_correct/2/count))
print('Match Accuracy = {}'.format(linear_match_correct/count))
# Out:
# Linear Model Results:
# MSE = 4.445531399135202
# Score Accuracy = 0.2612681436210848
# Match Accuracy = 0.4856124267888974

# %%
print('Random Forest Model Results:')
print('MSE = {}'.format(forest_SSE/count))
print('Score Accuracy = {}'.format(forest_score_correct/2/count))
print('Match Accuracy = {}'.format(forest_match_correct/count))
# Out:
# Random Forest Model Results:
# MSE = 4.44559879052785
# Score Accuracy = 0.3025210084033613
# Match Accuracy = 0.4703335879806468

# %% [markdown]
# ## Conclusion
#
# Alright, so both of the models developed had a poor track record in testing although that could have been gleaned from the poor $R^2$ reported by the model scores. The models are ok at predicting game outcomes doing better than a random guess which would have about a 33% accuracy but should not be used to get final scores. I did group a lot of leagues together and so moving forward I would probably recommend getting league specific models to predict results or more of a detailed attribute listing towards specific players.
